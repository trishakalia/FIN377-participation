# %% [markdown]
# # Practicing on Diamond

# %% [markdown]
# #Tall dataset- more columns less rows

# %%
import pandas as pd 
import seaborn as sns
import numpy as np

diamonds = sns.load_dataset('diamonds')
diamonds # notice shape, unit, key, etc...
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7       0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8       0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9       0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10      0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11      0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12      0.22    Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 13      0.31      Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 14      0.20    Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 15      0.32    Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 16      0.30      Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 17      0.30       Good     J     SI1   63.4   54.0    351  4.23  4.29  2.70
# 18      0.30       Good     J     SI1   63.8   56.0    351  4.23  4.26  2.71
# 19      0.30  Very Good     J     SI1   62.7   59.0    351  4.21  4.27  2.66
# 20      0.30       Good     I     SI2   63.3   56.0    351  4.26  4.30  2.71
# 21      0.23  Very Good     E     VS2   63.8   55.0    352  3.85  3.92  2.48
# 22      0.23  Very Good     H     VS1   61.0   57.0    353  3.94  3.96  2.41
# 23      0.31  Very Good     J     SI1   59.4   62.0    353  4.39  4.43  2.62
# 24      0.31  Very Good     J     SI1   58.1   62.0    353  4.44  4.47  2.59
# 25      0.23  Very Good     G    VVS2   60.4   58.0    354  3.97  4.01  2.41
# 26      0.24    Premium     I     VS1   62.5   57.0    355  3.97  3.94  2.47
# 27      0.30  Very Good     J     VS2   62.2   57.0    357  4.28  4.30  2.67
# 28      0.23  Very Good     D     VS2   60.5   61.0    357  3.96  3.97  2.40
# 29      0.23  Very Good     F     VS1   60.9   57.0    357  3.96  3.99  2.42
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53910   0.70    Premium     E     SI1   60.5   58.0   2753  5.74  5.77  3.48
# 53911   0.57    Premium     E      IF   59.8   60.0   2753  5.43  5.38  3.23
# 53912   0.61    Premium     F    VVS1   61.8   59.0   2753  5.48  5.40  3.36
# 53913   0.80       Good     G     VS2   64.2   58.0   2753  5.84  5.81  3.74
# 53914   0.84       Good     I     VS1   63.7   59.0   2753  5.94  5.90  3.77
# 53915   0.77      Ideal     E     SI2   62.1   56.0   2753  5.84  5.86  3.63
# 53916   0.74       Good     D     SI1   63.1   59.0   2753  5.71  5.74  3.61
# 53917   0.90  Very Good     J     SI1   63.2   60.0   2753  6.12  6.09  3.86
# 53918   0.76    Premium     I     VS1   59.3   62.0   2753  5.93  5.85  3.49
# 53919   0.76      Ideal     I    VVS1   62.2   55.0   2753  5.89  5.87  3.66
# 53920   0.70  Very Good     E     VS2   62.4   60.0   2755  5.57  5.61  3.49
# 53921   0.70  Very Good     E     VS2   62.8   60.0   2755  5.59  5.65  3.53
# 53922   0.70  Very Good     D     VS1   63.1   59.0   2755  5.67  5.58  3.55
# 53923   0.73      Ideal     I     VS2   61.3   56.0   2756  5.80  5.84  3.57
# 53924   0.73      Ideal     I     VS2   61.6   55.0   2756  5.82  5.84  3.59
# 53925   0.79      Ideal     I     SI1   61.6   56.0   2756  5.95  5.97  3.67
# 53926   0.71      Ideal     E     SI1   61.9   56.0   2756  5.71  5.73  3.54
# 53927   0.79       Good     F     SI1   58.1   59.0   2756  6.06  6.13  3.54
# 53928   0.79    Premium     E     SI2   61.4   58.0   2756  6.03  5.96  3.68
# 53929   0.71      Ideal     G     VS1   61.4   56.0   2756  5.76  5.73  3.53
# 53930   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53932   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
# 53933   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72  3.49
# 53934   0.72    Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
# my turn: lets do the usual immediate explorations including the categorical vars

diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
# my turn: explore carats - how many are 0.99 vs 1 carat? why?
diamonds['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
# my turn: explore carats - how many are 0.99 vs 1 carat? why?
sns.countplot(diamonds['carat'])

# %%
# my turn: explore carats - how many are 0.99 vs 1 carat? why?
sns.distplot(diamonds['carat'],kde=False,    #turns of density indicator
            bins=np.arange(0.2,2.05,.05).tolist())

# %%
# box plot 
sns.boxplot(x='carat', data=diamonds)

# %%
#violin plot 
sns.violinplot(x='carat', data=diamonds)

# %%
# explore dist of x, y, z: what did you learn? which is width, length, depth?
#sns.scatterplot(data=diamonds.query('y < 20 & x > 2.5'), x='x', y= 'y') # scatterplot
sns.jointplot(data=diamonds.query('y < 20 & x > 2.5'), x='x', y= 'y') # jointplot

# %%
# your turn: explore price - is there anything unusual? (HINT: try many bin widths)

sns.distplot(diamonds.query('price<5000')['price'],kde=False, 
            bins=200)

# %%
# my turn: how is carat related to price?
# sns.jointplot(data=diamonds.query('carat < 2.2 & price<10000'), y='price', x='carat', kind ='hex')
sns.jointplot(data=diamonds.query('carat < 1.5 & price<10000'), y='price', x='carat', kind ='kde') #kind = 'resid' , 'reg'

# %%
# your turn: how is price related to cut?
sns.boxplot(data=diamonds.query('price < 6000'), x='cut', y='price')
# how should we deal with outliers? delete obs? replace with nan? winsorize? show each...

# %%
import pandas as pd
import numpy as np
import pandas_datareader as pdr # you might need to install this (see above)
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# don't copy and paste these lists and number in several places 
# (which is what the original "simple program" did... that's bad programming!)
# instead, create a var - if we change it here, it changes everywhere
stocks = ['AAPL','MSFT','VZ']
start_yr = 2000

# load
stock_prices = pdr.get_data_yahoo(stocks, start=start_yr)
stock_prices = stock_prices.filter(like='Adj Close') # reduce to just columns with this in the name
stock_prices.columns = stocks # put their tickers as column names
stock_prices # print
# Out:
#                   AAPL        MSFT         VZ
# Date
# 2000-01-03    3.470226   37.393559  20.721500
# 2000-01-04    3.177650   36.130390  20.051672
# 2000-01-05    3.224152   36.511333  20.721500
# 2000-01-06    2.945139   35.288280  20.631170
# 2000-01-07    3.084645   35.749432  20.478834
# 2000-01-10    3.030393   36.010086  20.370028
# 2000-01-11    2.875386   35.087776  20.179594
# 2000-01-12    2.702940   33.944916  19.499504
# 2000-01-13    2.999391   34.586529  19.347162
# 2000-01-14    3.113708   36.010086  19.608315
# 2000-01-18    3.222214   36.992538  20.457071
# 2000-01-19    3.303592   34.325859  20.065342
# 2000-01-20    3.518665   34.005070  20.130632
# 2000-01-21    3.450849   33.283268  20.914082
# 2000-01-24    3.293904   32.481255  20.935856
# 2000-01-25    3.479914   32.982513  20.370028
# 2000-01-26    3.415973   31.879766  20.108871
# 2000-01-27    3.410160   31.679253  20.282974
# 2000-01-28    3.150523   31.518864  20.065342
# 2000-01-31    3.216401   31.398542  21.566982
# 2000-02-01    3.107896   33.022614  20.739992
# 2000-02-02    3.063332   32.340912  20.652943
# 2000-02-03    3.202839   33.243168  20.348259
# 2000-02-04    3.348157   34.185516  20.391788
# 2000-02-07    3.536104   34.205570  20.805283
# 2000-02-08    3.561293   35.268219  20.544127
# 2000-02-09    3.491539   33.363464  20.130632
# 2000-02-10    3.518665   34.005070  19.869478
# 2000-02-11    3.371409   32.060196  19.499504
# 2000-02-14    3.590356   31.959949  19.260120
# ...                ...         ...        ...
# 2020-01-08  302.472137  159.653915  59.094997
# 2020-01-09  308.896912  161.648468  58.849998
# 2020-01-10  309.595215  160.900513  58.990002
# 2020-01-13  316.209534  162.835236  59.150002
# 2020-01-14  311.939667  161.688370  59.040001
# 2020-01-15  310.602844  162.735504  59.099998
# 2020-01-16  314.493591  165.717361  59.669998
# 2020-01-17  317.975372  166.644836  60.130001
# 2020-01-21  315.820465  166.046463  60.320000
# 2020-01-22  316.947815  165.248642  60.480000
# 2020-01-23  318.474182  166.265869  60.509998
# 2020-01-24  317.556335  164.590439  60.279999
# 2020-01-27  308.218506  161.837952  59.910000
# 2020-01-28  316.937805  165.009308  60.700001
# 2020-01-29  323.572052  167.582260  59.529999
# 2020-01-30  323.103180  172.309357  59.360001
# 2020-01-31  308.777191  169.766296  59.439999
# 2020-02-03  307.929199  173.904999  58.049999
# 2020-02-04  318.095062  179.629364  58.290001
# 2020-02-05  320.688934  179.409958  59.130001
# 2020-02-06  324.440002  183.129807  59.439999
# 2020-02-07  320.029999  183.389099  59.939999
# 2020-02-10  321.549988  188.185989  60.240002
# 2020-02-11  319.609985  183.937607  58.689999
# 2020-02-12  327.200012  184.206863  58.230000
# 2020-02-13  324.869995  183.209595  58.650002
# 2020-02-14  324.950012  184.845123  58.509998
# 2020-02-18  319.000000  186.720001  57.910000
# 2020-02-19  323.619995  187.279999  58.220001
# 2020-02-20  320.299988  184.419998  58.040001
#
# [5065 rows x 3 columns]

# %%
# this is wide data... so if we want to create a new variable, we have to do it once for each firm...
# what if we have 1000 firms? seems tough to do...
# make long/tidy:
#stock_prices = stock_prices.stack().swaplevel().sort_index().reset_index()
#stock_prices.columns = ['Firm','Date','Adj Close']
stock_prices.stack().swaplevel().sort_index().reset_index() # print - now that is formatted nicely, like CRSP! 
stock_prices.columns = ['Firm','Date','Adj Close']
stock_prices

# note: we might have to tweak the regression section of "Simple Program"
# to work with the long data, but I suspect that it would be shorter code and 
# more "generally applicable" (ie easily work with N=1000+ firms)
# Out:
#                   Firm        Date  Adj Close
# Date
# 2000-01-03    3.470226   37.393559  20.721500
# 2000-01-04    3.177650   36.130390  20.051672
# 2000-01-05    3.224152   36.511333  20.721500
# 2000-01-06    2.945139   35.288280  20.631170
# 2000-01-07    3.084645   35.749432  20.478834
# 2000-01-10    3.030393   36.010086  20.370028
# 2000-01-11    2.875386   35.087776  20.179594
# 2000-01-12    2.702940   33.944916  19.499504
# 2000-01-13    2.999391   34.586529  19.347162
# 2000-01-14    3.113708   36.010086  19.608315
# 2000-01-18    3.222214   36.992538  20.457071
# 2000-01-19    3.303592   34.325859  20.065342
# 2000-01-20    3.518665   34.005070  20.130632
# 2000-01-21    3.450849   33.283268  20.914082
# 2000-01-24    3.293904   32.481255  20.935856
# 2000-01-25    3.479914   32.982513  20.370028
# 2000-01-26    3.415973   31.879766  20.108871
# 2000-01-27    3.410160   31.679253  20.282974
# 2000-01-28    3.150523   31.518864  20.065342
# 2000-01-31    3.216401   31.398542  21.566982
# 2000-02-01    3.107896   33.022614  20.739992
# 2000-02-02    3.063332   32.340912  20.652943
# 2000-02-03    3.202839   33.243168  20.348259
# 2000-02-04    3.348157   34.185516  20.391788
# 2000-02-07    3.536104   34.205570  20.805283
# 2000-02-08    3.561293   35.268219  20.544127
# 2000-02-09    3.491539   33.363464  20.130632
# 2000-02-10    3.518665   34.005070  19.869478
# 2000-02-11    3.371409   32.060196  19.499504
# 2000-02-14    3.590356   31.959949  19.260120
# ...                ...         ...        ...
# 2020-01-08  302.472137  159.653915  59.094997
# 2020-01-09  308.896912  161.648468  58.849998
# 2020-01-10  309.595215  160.900513  58.990002
# 2020-01-13  316.209534  162.835236  59.150002
# 2020-01-14  311.939667  161.688370  59.040001
# 2020-01-15  310.602844  162.735504  59.099998
# 2020-01-16  314.493591  165.717361  59.669998
# 2020-01-17  317.975372  166.644836  60.130001
# 2020-01-21  315.820465  166.046463  60.320000
# 2020-01-22  316.947815  165.248642  60.480000
# 2020-01-23  318.474182  166.265869  60.509998
# 2020-01-24  317.556335  164.590439  60.279999
# 2020-01-27  308.218506  161.837952  59.910000
# 2020-01-28  316.937805  165.009308  60.700001
# 2020-01-29  323.572052  167.582260  59.529999
# 2020-01-30  323.103180  172.309357  59.360001
# 2020-01-31  308.777191  169.766296  59.439999
# 2020-02-03  307.929199  173.904999  58.049999
# 2020-02-04  318.095062  179.629364  58.290001
# 2020-02-05  320.688934  179.409958  59.130001
# 2020-02-06  324.440002  183.129807  59.439999
# 2020-02-07  320.029999  183.389099  59.939999
# 2020-02-10  321.549988  188.185989  60.240002
# 2020-02-11  319.609985  183.937607  58.689999
# 2020-02-12  327.200012  184.206863  58.230000
# 2020-02-13  324.869995  183.209595  58.650002
# 2020-02-14  324.950012  184.845123  58.509998
# 2020-02-18  319.000000  186.720001  57.910000
# 2020-02-19  323.619995  187.279999  58.220001
# 2020-02-20  320.299988  184.419998  58.040001
#
# [5065 rows x 3 columns]

# %%
# Replicate and then improve each of the three figures 
# are there any issues with this data as in? how would you fix it? 
sns.distplot(stock_prices['ret'].dropna(),kde= False)

# %%
stock_prices['ret'] = stock_prices.groupby('Firm')['Adj Close'].pct_change()
print(stock_prices.head())
# Out:
#                 Firm       Date  Adj Close  ret
# Date
# 2000-01-03  3.470226  37.393559  20.721500  NaN
# 2000-01-04  3.177650  36.130390  20.051672  NaN
# 2000-01-05  3.224152  36.511333  20.721500  NaN
# 2000-01-06  2.945139  35.288280  20.631170  NaN
# 2000-01-07  3.084645  35.749432  20.478834  NaN

# %%
# Q1: Check that there are 3 missing observations of ret: the first return for each shouldn't exist.

stock_prices['ret'].isna().sum()

# help(stock_prices['ret'].isnull()
# Out:
# 4667

# %%
# Q2: Describe returns for each firm separately (i.e. make one table), and your answers should match mine below.
stock_prices.groupby('Firm')    ['ret'].describe()
# Out:
#             count      mean       std       min       25%       50%       75%  \
# Firm
# 0.813478      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.814718      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.818438      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.820919      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.827739      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.830219      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.833319      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.837659      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.842000      1.0  0.037730       NaN  0.037730  0.037730  0.037730  0.037730
# 0.842620      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.848200      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.853780      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.855640      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.859360      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.860600      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.867421      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.868041      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.869281      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.869901      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.871141      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.871761      1.0 -0.029490       NaN -0.029490 -0.029490 -0.029490 -0.029490
# 0.871916      1.0 -0.117514       NaN -0.117514 -0.117514 -0.117514 -0.117514
# 0.872381      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.874241      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.874861      1.0  0.085280       NaN  0.085280  0.085280  0.085280  0.085280
# 0.876101      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.876721      2.0  0.100221  0.293749 -0.107491 -0.003635  0.100221  0.204077
# 0.877341      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.877961      0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 0.878581      2.0  0.106228  0.150229  0.000000  0.053114  0.106228  0.159342
# ...           ...       ...       ...       ...       ...       ...       ...
# 302.472137    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 307.929199    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 308.218506    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 308.777191    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 308.896912    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 309.595215    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 310.602844    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 311.939667    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 314.493591    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 315.820465    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 316.209534    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 316.937805    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 316.947815    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 317.556335    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 317.975372    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 318.095062    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 318.474182    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 319.000000    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 319.609985    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 320.029999    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 320.299988    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 320.688934    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 321.549988    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 323.103180    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 323.572052    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 323.619995    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 324.440002    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 324.869995    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 324.950012    0.0       NaN       NaN       NaN       NaN       NaN       NaN
# 327.200012    0.0       NaN       NaN       NaN       NaN       NaN       NaN
#
#                  max
# Firm
# 0.813478         NaN
# 0.814718         NaN
# 0.818438         NaN
# 0.820919         NaN
# 0.827739         NaN
# 0.830219         NaN
# 0.833319         NaN
# 0.837659         NaN
# 0.842000    0.037730
# 0.842620         NaN
# 0.848200         NaN
# 0.853780         NaN
# 0.855640         NaN
# 0.859360         NaN
# 0.860600         NaN
# 0.867421         NaN
# 0.868041         NaN
# 0.869281         NaN
# 0.869901         NaN
# 0.871141         NaN
# 0.871761   -0.029490
# 0.871916   -0.117514
# 0.872381         NaN
# 0.874241         NaN
# 0.874861    0.085280
# 0.876101         NaN
# 0.876721    0.307933
# 0.877341         NaN
# 0.877961         NaN
# 0.878581    0.212456
# ...              ...
# 302.472137       NaN
# 307.929199       NaN
# 308.218506       NaN
# 308.777191       NaN
# 308.896912       NaN
# 309.595215       NaN
# 310.602844       NaN
# 311.939667       NaN
# 314.493591       NaN
# 315.820465       NaN
# 316.209534       NaN
# 316.937805       NaN
# 316.947815       NaN
# 317.556335       NaN
# 317.975372       NaN
# 318.095062       NaN
# 318.474182       NaN
# 319.000000       NaN
# 319.609985       NaN
# 320.029999       NaN
# 320.299988       NaN
# 320.688934       NaN
# 321.549988       NaN
# 323.103180       NaN
# 323.572052       NaN
# 323.619995       NaN
# 324.440002       NaN
# 324.869995       NaN
# 324.950012       NaN
# 327.200012       NaN
#
# [4667 rows x 8 columns]

# %%
## q3 fig 1 
sns.distplot(stock_prices.query('abs(ret)<.1')     ['ret'].dropna()) # dropna drops the null values

# %%
## q3 fig 2
sns.boxplot(x='ret', data=stock_prices.query('abs(ret)<.1'))

# %%
## q3 fig 3 

sns.lineplot(data=stock_prices.query('ret>=0.3'), x='Date', y='ret', hue='Firm')
