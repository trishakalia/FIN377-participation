# %% [markdown]
# # EXTRA CREDIT

# %% [markdown]
# # Opportunity 1:

# %%
#!pip install tqdm              # run this one time to install if you don't have it
#!pip install requests_html     # run this one time to install if you don't have it

import pandas as pd
from requests_html import HTMLSession
import os
import re
from time import sleep
from tqdm.notebook import tqdm # progress bar

session = HTMLSession()

# %%
session = HTMLSession() 
url = 'https://en.m.wikipedia.org/wiki/List_of_S%26P_500_companies'
r = session.get(url)
r.html.links # gives all the relative links  - you cant click on them 
r.html.absolute_links # makes this clickable immediately- you can clink on all of them 

# get the tabe 
r.html.find('table')  #[0]
table = r.html.find('#constituents') [0] # id so use # sign 
table.text # just text 
table.html # print html 

# blunt force the table! 
table.absolute_links # extracted all urls from the table. still too many links but can "dumb filter"
 #pd.read_html(table.html)- only gives html tho 
r.html.links # gives all the relative links  - you cant click on them 
r.html.absolute_links # makes this clickable immediately- you can clink on all of them 

# get the tabe 
r.html.find('table')  #[0]
table = r.html.find('#constituents') [0] # id so use # sign 
table.text # just text 
table.html # print html 

# blunt force the table! 
table.absolute_links # extracted all urls from the table. still too many links but can "dumb filter"
 #pd.read_html(table.html)- only gives html tho 
table.find('tr')[0].text # header...we dont want that!
table.find('tr')[1].text

table_rows = table.find('tr')

colinks = []
for row in table_rows[1:]:
    print(row.find('td')[1].absolute_links) # got swuigly bracket so a set 
 # colink append  
    a_link = list(row.find('td')[1].absolute_links)[0] 
    colinks.append(a_link)
len(colinks)
# Out:
# {'https://en.m.wikipedia.org/wiki/3M'}
# {'https://en.m.wikipedia.org/wiki/Abbott_Laboratories'}
# {'https://en.m.wikipedia.org/wiki/AbbVie_Inc.'}
# {'https://en.m.wikipedia.org/wiki/Abiomed'}
# {'https://en.m.wikipedia.org/wiki/Accenture_plc'}
# {'https://en.m.wikipedia.org/wiki/Activision_Blizzard'}
# {'https://en.m.wikipedia.org/wiki/Adobe_Inc.'}
# {'https://en.m.wikipedia.org/wiki/Advanced_Micro_Devices_Inc'}
# {'https://en.m.wikipedia.org/wiki/Advance_Auto_Parts'}
# {'https://en.m.wikipedia.org/wiki/AES_Corp'}
# {'https://en.m.wikipedia.org/wiki/AFLAC_Inc'}
# {'https://en.m.wikipedia.org/wiki/Agilent_Technologies_Inc'}
# {'https://en.m.wikipedia.org/wiki/Air_Products_%26_Chemicals_Inc'}
# {'https://en.m.wikipedia.org/wiki/Akamai_Technologies_Inc'}
# {'https://en.m.wikipedia.org/wiki/Alaska_Air_Group_Inc'}
# {'https://en.m.wikipedia.org/wiki/Albemarle_Corp'}
# {'https://en.m.wikipedia.org/wiki/Alexandria_Real_Estate_Equities'}
# {'https://en.m.wikipedia.org/wiki/Alexion_Pharmaceuticals'}
# {'https://en.m.wikipedia.org/wiki/Align_Technology'}
# {'https://en.m.wikipedia.org/wiki/Allegion'}
# {'https://en.m.wikipedia.org/wiki/Allergan,_plc'}
# {'https://en.m.wikipedia.org/wiki/Alliance_Data_Systems'}
# {'https://en.m.wikipedia.org/wiki/Alliant_Energy_Corp'}
# {'https://en.m.wikipedia.org/wiki/Allstate_Corp'}
# {'https://en.m.wikipedia.org/wiki/Alphabet_Inc.'}
# {'https://en.m.wikipedia.org/wiki/Alphabet_Inc.'}
# {'https://en.m.wikipedia.org/wiki/Altria_Group_Inc'}
# {'https://en.m.wikipedia.org/wiki/Amazon.com_Inc.'}
# {'https://en.m.wikipedia.org/wiki/
Inc.'}
# {'https://en.m.wikipedia.org/wiki/Western_Digital'}
# {'https://en.m.wikipedia.org/wiki/Western_Union_Co'}
# {'https://en.m.wikipedia.org/wiki/WestRock'}
# {'https://en.m.wikipedia.org/wiki/Weyerhaeuser'}
# {'https://en.m.wikipedia.org/wiki/Whirlpool_Corp.'}
# {'https://en.m.wikipedia.org/wiki/Williams_Cos.'}
# {'https://en.m.wikipedia.org/wiki/Willis_Towers_Watson'}
# {'https://en.m.wikipedia.org/wiki/Wynn_Resorts_Ltd'}
# {'https://en.m.wikipedia.org/wiki/Xcel_Energy_Inc'}
# {'https://en.m.wikipedia.org/wiki/Xerox'}
# {'https://en.m.wikipedia.org/wiki/Xilinx'}
# {'https://en.m.wikipedia.org/wiki/Xylem_Inc.'}
# {'https://en.m.wikipedia.org/wiki/Yum!_Brands_Inc'}
# {'https://en.m.wikipedia.org/wiki/Zebra_Technologies'}
# {'https://en.m.wikipedia.org/wiki/Zimmer_Holdings'}
# {'https://en.m.wikipedia.org/wiki/Zions_Bancorp'}
# {'https://en.m.wikipedia.org/wiki/Zoetis'}
# 505

# %%
#### SECTION 1: get the urls to crawl (or data that can build the urls)

if not os.path.exists('input/sp500_urls.csv'):

    # open page
    session = HTMLSession() 
    url = 'https://en.m.wikipedia.org/wiki/List_of_S%26P_500_companies'
    r = session.get(url)

    # find the links
    table = r.html.find('#constituents')[0]  # reduce to the table
    table_rows = table.find('tr')[1:]
    colinks = []
    for row in table_rows:
        a_url =   list(row.find('td')[1].absolute_links)[0]    
        colinks.append(a_url)

# %%
  # save list to csv    
if not os.path.exists('input/'):
    os.makedirs('input/')
    pd.DataFrame(colinks).to_csv('input/sp500_urls.csv',index=False,header=False)
    
else:
    colinks = pd.read_csv('input/sp500_urls.csv',names=['firm']) ['firm'].to_list()

# %%
#### SECTION 2: crawl the urls

# for url in colinks[:10]:
for url in tqdm(colinks,total=len(colinks)):
    
    folder = 'wiki_html/'
    if not os.path.exists('wiki_html/'):
        os.makedirs('wiki_html/')
    
    name = re.sub( r'\W+','',     url.split('/')[-1]    )
    filepath = folder + name + '.txt'
        
    if not os.path.exists(filepath):
        
        try:
            r = session.get(url)
        except:
            print('sad face failure:',url)
        else:   
            with open(filepath,'w',encoding='utf8') as f:
                f.write(r.text)
            sleep(2) # be nice to server
# Out:
# HBox(children=(IntProgress(value=0, max=505), HTML(value='')))

# %% [markdown]
# # Opportunity 2:

# %%
data_read = pd.read_stata('https://github.com/LeDataSciFi/lectures-spr2020/blob/master/assignment_data/2007_inv_and_tech.dta?raw=true')
data_read.count()
# Out:
# index                      338
# gvkey                      338
# fyear                      338
# datadate                   338
# lpermno                    338
# sic                        338
# sic3                       338
# age                        338
# me                         338
# l_a                        338
# l_sale                     338
# prof_a                     338
# mb                         338
# ppe_a                      338
# xrd_a                      338
# cash_a                     338
# div_d                      338
# td                         334
# td_a                       334
# td_mv                      334
# dltt_a                     334
# dv_a                       338
# invopps_FG09               307
# sales_g                    333
# tnic3hhi                   303
# tnic3tsimm                 303
# prodmktfluid               298
# delaycon                   256
# l_emp                      335
# l_ppent                    338
# l_laborratio               334
# l_stock_grant_citew        338
# l_stock_trans_in_citew     322
# l_stock_trans_out_citew    322
# CIK                        148
# FDATE                      148
# Form                       338
# CoName                     338
# FName                      338
# dtype: int64

# %%
session = HTMLSession()

#### SECTION 1: get the urls to crawl (or data that can build the urls)

if not os.path.exists('2007_inv_and_tech.dta'):

    # open page
    session = HTMLSession() 
    url = 'https://github.com/LeDataSciFi/lectures-spr2020/blob/master/assignment_data/2007_inv_and_tech.dta?raw=true'
    r = session.get(url)

    # find the links
    table = r.html.find('FName')[0]  # reduce to the table
    table_rows = table.find('tr')[1:]
    colinks = []
    for row in table_rows:
        a_url =   list(row.find('td')[1].absolute_links)[0]    
        colinks.append(a_url)

    # save list to csv    
    if not os.path.exists('2007_inv_and_tech.dta'):
        os.makedirs('2007_inv_and_tech.dta')
    pd.DataFrame(colinks).to_stata('2007_inv_and_tech.dta',index=False,header=False)
    
else:
    colinks = pd.read_stata('2007_inv_and_tech.dta',['CoName']) ['CoName'].to_list()


#### SECTION 2: crawl the urls

# for url in colinks[:10]:
for url in tqdm(colinks,total=len(colinks)):
    
    folder = 'wiki_html/'
    if not os.path.exists('wiki_html/'):
        os.makedirs('wiki_html/')
    
    name = re.sub( r'\W+','',     url.split('/')[-1]    )
    filepath = folder + name + '.txt'
        
    if not os.path.exists(filepath):
        
        try:
            r = session.get(url)
        except:
            print('sad face failure:',url)
        else:   
            with open(filepath,'w',encoding='utf8') as f:
                f.write(r.text)
            sleep(2) # be nice to server
# Out:
# HBox(children=(IntProgress(value=0, max=338), HTML(value='')))
# sad face failure: ABM INDUSTRIES INC /DE/
# sad face failure:
# sad face failure: ANALYSTS INTERNATIONAL CORP
# sad face failure:
# sad face failure: AUTODESK INC
# sad face failure:
# sad face failure: AUTOMATIC DATA PROCESSING INC
# sad face failure:
# sad face failure: UNISYS CORP
# sad face failure:
# sad face failure: ACXIOM CORP
# sad face failure:
# sad face failure: CDI CORP
# sad face failure:
# sad face failure: CSP INC /MA/
# sad face failure:
# sad face failure: CACI INTERNATIONAL INC /DE/
# sad face failure:
# sad face failure: CA, INC.
# sad face failure:
# sad face failure: COMPUTER TASK GROUP INC
# sad face failure:
# sad face failure: DST SYSTEMS INC
# sad face failure:
# sad face failure: DYNAMICS RESEARCH CORP
# sad face failure:
# sad face failure: EQUIFAX INC
# sad face failure:
# sad face failure: CONVERA CORP
# sad face failure:
# sad face failure: INTERNATIONAL BUSINESS MACHINES CORP
# sad face failure:
# sad face failure: KELLY SERVICES INC
# sad face failure:
# sad face failure: MENTOR GRAPHICS CORP
# sad face failure:
# sad face failure: NEWTEK BUSINESS SERVICES INC
# sad face failure:
# sad face failure: ROLLINS INC
# sad face failure:
# sad face failure: TSR INC
# sad face failure:
# sad face failure: TOTAL SYSTEM SERVICES INC
# sad face failure:
# sad face failure: TYLER TECHNOLOGIES INC
# sad face failure:
# sad face failure: VOLT INFORMATION SCIENCES, INC.
# sad face failure:
# sad face failure: NOVELL INC
# sad face failure:
# sad face failure: MICROSOFT CORP
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: CADENCE DESIGN SYSTEMS INC
# sad face failure:
# sad face failure: FAIR ISAAC CORP
# sad face failure:
# sad face failure: BORLAND SOFTWARE CORP
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: PHOENIX TECHNOLOGIES LTD
# sad face failure:
# sad face failure: BMC SOFTWARE INC
# sad face failure:
# sad face failure: SYMANTEC CORP
# sad face failure:
# sad face failure: CONSULIER ENGINEERING INC
# sad face failure:
# sad face failure: ZIX CORP
# sad face failure:
# sad face failure: ELECTRONIC ARTS INC.
# sad face failure:
# sad face failure: COREL CORP
# sad face failure:
# sad face failure: PARAMETRIC TECHNOLOGY CORP
# sad face failure:
# sad face failure: TRUEBLUE, INC.
# sad face failure:
# sad face failure: PROGRESS SOFTWARE CORP /MA
# sad face failure:
# sad face failure: SYBASE INC
# sad face failure:
# sad face failure: SYNOPSYS INC
# sad face failure:
# sad face failure: FORGENT NETWORKS INC
# sad face failure:
# sad face failure: MCAFEE, INC.
# sad face failure:
# sad face failure: COMPUWARE CORP
# sad face failure:
# sad face failure: IAC/INTERACTIVECORP
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: INTUIT INC
# sad face failure:
# sad face failure: WIND RIVER SYSTEMS INC
# sad face failure:
# sad face failure: BRINKS CO
# sad face failure:
# sad face failure: INCYTE CORP
# sad face failure:
# sad face failure: SONIC SOLUTIONS/CA/
# sad face failure:
# sad face failure: NATIONAL INSTRUMENTS CORP /DE/
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: GSE SYSTEMS INC
# sad face failure:
# sad face failure: ADVENT SOFTWARE INC /DE/
# sad face failure:
# sad face failure: ACCELRYS, INC.
# sad face failure:
# sad face failure: CITRIX SYSTEMS INC
# sad face failure:
# sad face failure: NUANCE COMMUNICATIONS, INC.
# sad face failure:
# sad face failure: ADEPT TECHNOLOGY INC
# sad face failure:
# sad face failure: OPEN TEXT CORP
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: CSG SYSTEMS INTERNATIONAL INC
# sad face failure:
# sad face failure: SPAR GROUP INC
# sad face failure:
# sad face failure: EARTHLINK INC
# sad face failure:
# sad face failure: JDA SOFTWARE GROUP INC
# sad face failure:
# sad face failure: SAPIENT CORP
# sad face failure:
# sad face failure: YAHOO INC
# sad face failure:
# sad face failure: I2 TECHNOLOGIES INC
# sad face failure:
# sad face failure: ANSYS INC
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: AWARE INC /MA/
# sad face failure:
# sad face failure: PEERLESS SYSTEMS CORP
# sad face failure:
# sad face failure: BITSTREAM INC
# sad face failure:
# sad face failure: MIDWAY GAMES INC
# sad face failure:
# sad face failure: VOXWARE INC
# sad face failure:
# sad face failure: SEACHANGE INTERNATIONAL INC
# sad face failure:
# sad face failure: L-1 IDENTITY SOLUTIONS, INC.
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: IGATE CORP
# sad face failure:
# sad face failure: MEDIALINK WORLDWIDE INC
# sad face failure:
# sad face failure: ERESEARCHTECHNOLOGY INC /DE/
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: VITAL IMAGES INC
# sad face failure:
# sad face failure: STARTEK INC
# sad face failure:
# sad face failure: AMICAS, INC.
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: RENAISSANCE LEARNING INC
# sad face failure:
# sad face failure: PERVASIVE SOFTWARE INC
# sad face failure:
# sad face failure: REALNETWORKS INC
# sad face failure:
# sad face failure: TIER TECHNOLOGIES INC
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: MERCURY COMPUTER SYSTEMS INC
# sad face failure:
# sad face failure: MERGE HEALTHCARE INC
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: SONIC FOUNDRY INC
# sad face failure:
# sad face failure: MANHATTAN ASSOCIATES INC
# sad face failure:
# sad face failure: EVOLVING SYSTEMS INC
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: ECLIPSYS CORP
# sad face failure:
# sad face failure: SCIENTIFIC LEARNING CORP
# sad face failure:
# sad face failure: CONVERGYS CORP
# sad face failure:
# sad face failure: CROWN CASTLE INTERNATIONAL CORP
# sad face failure:
# sad face failure: ENTRUST INC
# sad face failure:
# sad face failure: EBAY INC
# sad face failure:
# sad face failure: WEBMD HEALTH CORP.
# sad face failure:
# sad face failure: ON2 TECHNOLOGIES, INC.
# sad face failure:
# sad face failure: PEROT SYSTEMS CORP
# sad face failure:
# sad face failure: BOTTOMLINE TECHNOLOGIES INC /DE/
# sad face failure:
# sad face failure: VIGNETTE CORP
# sad face failure:
# sad face failure: PRICELINE COM INC
# sad face failure:
# sad face failure: INFORMATICA CORP
# sad face failure:
# sad face failure: S1 CORP /DE/
# sad face failure:
# sad face failure: ONLINE RESOURCES CORP
# sad face failure:
# sad face failure: OPENWAVE SYSTEMS INC
# sad face failure:
# sad face failure: ARIBA INC
# sad face failure:
# sad face failure: CYBERSOURCE CORP
# sad face failure:
# sad face failure: ART TECHNOLOGY GROUP INC
# sad face failure:
# sad face failure: INSWEB CORP
# sad face failure:
# sad face failure: NETSCOUT SYSTEMS INC
# sad face failure:
# sad face failure: MAJESCO ENTERTAINMENT CO
# sad face failure:
# sad face failure: QUEST SOFTWARE INC
# sad face failure:
# sad face failure: LIONBRIDGE TECHNOLOGIES INC /DE/
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: KEYNOTE SYSTEMS INC
# sad face failure:
# sad face failure: UNITED ONLINE INC
# sad face failure:
# sad face failure: INTERNAP NETWORK SERVICES CORP
# sad face failure:
# sad face failure: INTERWOVEN INC
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: BSQUARE CORP /WA
# sad face failure:
# sad face failure: OPENTV CORP
# sad face failure:
# sad face failure: CHORDIANT SOFTWARE INC
# sad face failure:
# sad face failure: SAVVIS, INC.
# sad face failure:
# sad face failure: SELECTICA INC
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: WEBSENSE INC
# sad face failure:
# sad face failure: SUPPORTSOFT INC
# sad face failure:
# sad face failure: SABA SOFTWARE INC
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: SONUS NETWORKS INC
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: NETWORK ENGINES INC
# sad face failure:
# sad face failure: OPNET TECHNOLOGIES INC
# sad face failure:
# sad face failure: TELECOMMUNICATION SYSTEMS INC /FA/
# sad face failure:
# sad face failure: MAGMA DESIGN AUTOMATION INC
# sad face failure:
# sad face failure: LAWSON SOFTWARE, INC.
# sad face failure:
# sad face failure: PDF SOLUTIONS INC
# sad face failure:
# sad face failure: IPASS INC
# sad face failure:
# sad face failure: RIGHTNOW TECHNOLOGIES INC
# sad face failure:
# sad face failure: ANSWERS CORP
# sad face failure:
# sad face failure: COGENT, INC.
# sad face failure:
# sad face failure: VIAD CORP
# sad face failure:
# sad face failure: LOCAL.COM
# sad face failure:
# sad face failure: ARBINET THEXCHANGE INC
# sad face failure:
# sad face failure: VIRTUALSCOPICS, INC.
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: DIVX INC
# sad face failure:
# sad face failure: OMNITURE, INC.
# sad face failure:
# sad face failure: SHUTTERFLY INC
# sad face failure:
# sad face failure: SOURCEFIRE INC
# sad face failure:
# sad face failure: BIGBAND NETWORKS, INC.
# sad face failure:
# sad face failure: LIMELIGHT NETWORKS, INC.
# sad face failure:
# sad face failure: DEMANDTEC, INC.
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure:
# sad face failure: ACTIVIDENTITY CORP
# sad face failure:
# sad face failure: PHASE FORWARD INC
# sad face failure:
